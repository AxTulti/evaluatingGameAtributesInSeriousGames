# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Importante
# Desiciones del preprocessamiento por verificar:
#  - Clasificación de columnas

# %% [markdown]
# ### Data Path

# %%
DATA_PATH = './data/resultados_encuesta.xlsx'
EXPORT_PATH = './data/cleaned_data.xlsx'

df_raw = pd.read_excel(DATA_PATH)
df = df_raw.copy()

# %% [markdown]
# # Preprocessing of Data

# %% [markdown]
# ## Remove Non-numerical Features
# Since those are only used for segmentation

# %%
df = df.iloc[:, 4:]

# %%
df
# Out:
#      desafio_importancia  desafio_calificacion  retroalimentacion_importancia  \
# 0                     10                    10                             10
# 1                      8                     8                              8
# 2                     10                    10                              9
# 3                      8                     8                              8
# 4                      9                     9                              9
# ..                   ...                   ...                            ...
# 152                    8                     8                              9
# 153                    8                    10                              5
# 154                    8                     6                              8
# 155                   10                    10                             10
# 156                   10                     8                             10
#
#      retroalimentacion_calificacion  inmersion_importancia  \
# 0                                10                     10
# 1                                 8                      8
# 2                                 7                     10
# 3                                 9                      9
# 4                                 9                      9
# ..                              ...                    ...
# 152                               7                      8
# 153                               7                      1
# 154                               2                      3
# 155                               3                      7
# 156                               5                     10
#
#      inmersion_calificacion  concentracion_importancia  \
# 0                        10                         10
# 1                         7                          8
# 2                         8                          9
# 3                         9                          9
# 4                         9                          7
# ..                      ...                        ...
# 152                       8                          8
# 153                       8                         10
# 154                       4                          8
# 155                       6                         10
# 156                       7                         10
#
#      concentracion_calificacion  claridad_de_objetivos_importancia  \
# 0                            10                                 10
# 1                             8                                  8
# 2                             9                                 10
# 3                             8                                  9
# 4                             5                                  8
# ..                          ...                                ...
# 152                           8                                  8
# 153                          10                                 10
# 154                           6                                  8
# 155                           9                                 10
# 156                           8                                 10
#
#      claridad_de_objetivos_calificacion  ...  \
# 0                                    10  ...
# 1                                     8  ...
# 2                                    10  ...
# 3                                     9  ...
# 4                                     8  ...
# ..                                  ...  ...
# 152                                   8  ...
# 153                                  10  ...
# 154                                   8  ...
# 155                                  10  ...
# 156                                   9  ...
#
#      involucramiento_emocional_calificacion  \
# 0                                        10
# 1                                         8
# 2                                        10
# 3                                         9
# 4                                         3
# ..                                      ...
# 152                                       7
# 153                                       3
# 154                                       7
# 155                                       5
# 156                                       8
#
#      equilibrio_entre_habilidades_y_tareas_importancia  \
# 0                                                   10
# 1                                                    8
# 2                                                   10
# 3                                                    9
# 4                                                    4
# ..                                                 ...
# 152                                                  9
# 153                                                 10
# 154                                                  8
# 155                                                 10
# 156                                                 10
#
#      equilibrio_entre_habilidades_y_tareas_calificacion  \
# 0                                                   10
# 1                                                    8
# 2                                                    9
# 3                                                    9
# 4                                                    4
# ..                                                 ...
# 152                                                  8
# 153                                                  8
# 154                                                  8
# 155                                                  9
# 156                                                  8
#
#      narrativa_atractiva_importancia  narrativa_atractiva_calificacion  \
# 0                                  6                                 6
# 1                                  8                                 8
# 2                                  8                                 8
# 3                                  9                                 9
# 4                                  4                                 5
# ..                               ...                               ...
# 152                               10                                 8
# 153                                5                                 1
# 154                                4                                 5
# 155                                3                                 1
# 156                               10                                10
#
#      estructura_de_progresion_importancia  \
# 0                                      10
# 1                                       8
# 2                                      10
# 3                                       9
# 4                                       5
# ..                                    ...
# 152                                    10
# 153                                    10
# 154                                     7
# 155                                     9
# 156                                    10
#
#      estructura_de_progresion_calificacion  animacion_y_sonido_importancia  \
# 0                                       10                               9
# 1                                        8                               8
# 2                                       10                              10
# 3                                        9                              10
# 4                                        9                               9
# ..                                     ...                             ...
# 152                                      9                               9
# 153                                     10                               3
# 154                                      8                               8
# 155                                      3                               7
# 156                                     10                              10
#
#      animacion_y_sonido_calificacion  calificacion_global
# 0                                  8                   10
# 1                                  8                    7
# 2                                 10                    9
# 3                                 10                    9
# 4                                  8                    9
# ..                               ...                  ...
# 152                                8                    8
# 153                                8                    7
# 154                                8                    8
# 155                                1                    8
# 156                                8                    8
#
# [157 rows x 27 columns]

# %% [markdown]
# ## Standarizing column names

# %% [markdown]
# ### We define a column Mapping

# %% [markdown]
# |Spanish Feature Concept      |Parent Category      |Importance Code|Rating Code|
# |-----------------------------|---------------------|---------------|-----------|
# |Desafío                      |Challenge            |CH1            |CH2        |
# |Equilibrio Habilidades/Tareas|Challenge            |CH3            |CH4        |
# |Estructura de Progresión     |Challenge            |CH5            |CH6        |
# |Inmersión                    |Immersion            |I1             |I2         |
# |Involucramiento Emocional    |Immersion            |I3             |I4         |
# |Narrativa Atractiva          |Immersion            |I5             |I6         |
# |Animación y Sonido           |Immersion            |I7             |I8         |
# |Concentración                |Concentration        |C1             |C2         |
# |Claridad de Objetivos        |Goal Clarity         |G1             |G2         |
# |Retroalimentación            |Feedback             |F1             |F2         |
# |Autonomía                    |Autonomy             |A1             |A2         |
# |Interacción Social           |Social Interaction   |S1             |S2         |
# |Mejora del Conocimiento      |Knowledge Improvement|K1             |K2         |
# |Calificación Global          |Overall              |O1             |—          |

# %%
old_cols = list(df.columns)
new_cols = [
    'CH1', 'CH2',  # Desafío
    'F1', 'F2',    # Retroalimentación
    'I1', 'I2',    # Inmersión
    'C1', 'C2',    # Concentración
    'G1', 'G2',    # Claridad de Objetivos
    'A1', 'A2',    # Autonomía
    'S1', 'S2',    # Interacción Social
    'K1', 'K2',    # Mejora del Conocimiento
    'I3', 'I4',    # Involucramiento Emocional
    'CH3', 'CH4',  # Equilibrio entre Habilidades y Tareas
    'I5', 'I6',    # Narrativa Atractiva
    'CH5', 'CH6',  # Estructura de Progresión
    'I7', 'I8',    # Animación y Sonido
    'O1'           # Calificación Global
]
normalization_mapping = dict(zip(old_cols, new_cols))

# %%
df.columns = [normalization_mapping.get(c) for c in df.columns]

# %% [markdown]
# ## Handling Missing Values

# %%
df.isna().sum()
# Out:
# CH1    0
# CH2    0
# F1     0
# F2     0
# I1     0
# I2     0
# C1     0
# C2     0
# G1     0
# G2     0
# A1     0
# A2     0
# S1     0
# S2     0
# K1     0
# K2     0
# I3     0
# I4     0
# CH3    0
# CH4    0
# I5     0
# I6     0
# CH5    0
# CH6    0
# I7     0
# I8     0
# O1     0
# dtype: int64

# %% [markdown]
# We skip filling missing values, since there are no missing values

# %% [markdown]
# ### Export

# %%
df.to_excel(EXPORT_PATH, index=False, sheet_name='data')
